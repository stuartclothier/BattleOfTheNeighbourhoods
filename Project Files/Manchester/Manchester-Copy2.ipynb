# %% [markdown]
# This version of the notebook seeks to access the boundaries of the districts from the HERE API

# %% [markdown]
# <h1><center>Discovering Manchester</center></h1>
#
# <h4><center> IBM Capstone Project - Exploring the best areas for a young professional to move to in Greater Manchester </center></h4>

# %% [markdown]
# ## [Table of Contents:](#Table-of-Contents:)
#
# * [Project Goals](#Project-Goals)
# * [Libraries](#Libraries)
# * [Data](#Data)
#     * [Areas](#Areas)
#         * [Metropolitan Districts](#Metropolitan-Districts:)
#         * [Wards](#Wards:)
#         * [Postcodes](#Postcodes:)
#         * [Nearby 'districts'](#Nearby-'districts')
#     * [Desirability](#Desirability)
# * [References](#References)

# %% [markdown]
# ## Project Goals
#
# This project seeks to analyse areas of Greater Manchester and seeks to answer the question; where are be the best locations for a young professional to move to?
#
# This notebook shows my thought process and approach to this project and the avenues I have explored in trying to reach my ultimate goal of area comparison in Manchester, as such some of these sections could be removed to add readability and make the notebook much more concise and clean.

# %% [markdown]
# ## Libraries
#
# The following libraries have been used in this Notebook:

# %%
import re
from urllib.request import urlopen

import pandas as pd
import numpy as np
import requests
import folium
from geopy.geocoders import Here
from bs4 import BeautifulSoup
from shapely.wkt import loads
from shapely.geometry import mapping
import geojson
import ast

# %% [markdown]
# ## Functions
#
# The following functions are used in this Notebook:

# %%
def cleanhtml(soup) -> list:
    ## This function converts tables from url (beautiful soup object) to a 
    ## list of strings with HTML formatting removed ##
    
    tables_html = soup.find_all('table')
    tables_html = [str(table_html).split('<tr>') for table_html in tables_html]
    cleaner = re.compile('<.*?>')
    tables = [[list(filter(None,re.sub(cleaner, '', line).splitlines())) 
               for line in table] for table in tables_html]
    
    return tables

# %% [markdown]
# ## Data
#
# ### Areas
#
# The first task in this project is to determine how the areas of Greater Manchester will be divided.
#
# Manchester is somewhat difficult to divide into clearly defined areas for historical reasons. Areas {EXPAND ON THIS}!!!!!!!!!!!!!!!!!!!!!!!  <sup>[1](#1.)</sup>
#
# The following options were considered:
#
# #### <b>Metropolitan Districts:</b><br>
#
# Greater Manchester comprises of ten metropolitan areas:
# 1. City of Manchester
# 2. Stockport
# 3. Tameside
# 4. Oldham
# 5. Rochdale
# 6. Bury
# 7. Bolton
# 8. Wigan
# 9. City of Salford
# 10. Trafford
#
# <figure>
# <img src="images/Greater_Manchester_numbered_districts.svg.png" style="width:500px;height:300px;">
# <figcaption>Image 2: Greater Manchester metropolitan districts. Source: Wikipedia.</figcaption>
# </figure>
# <br>
#
# PLACE SOME OBSERVATIONS HERE<br>
# <br>
#
# #### <b>Wards:</b><br>
#
# The City of Manchester countains contain 32 Wards<sup>[2](#2.)</sup>:
#
# <figure>
# <img src="Images/Ward-Map-Manchester_District_(B).jpg" style="width:500px;height:500px;">
# <figcaption>Image 2: Greater Manchester metropolitan districts. Source: Wikipedia.</figcaption>
# </figure>
# <br>
#
# PLACE SOME OBSERVATIONS HERE<br>
# <br>

# %% [markdown]
# #### <b>Postcodes</b>:
#
#
# Postcodes in the United Kingdom include a outward and an inward code. <br>
# The outward code comprised of a postcode area, a one or two letter code, and a postcode district, one or two digits or a digit followed by a letter. For example, Machester city centre has the outward postal code M1.<br>
# The inward code comprises of a single digit postcode sector followed by a two character postcode unit. A postal code may be a single street, or even a single building or organisation.<sup>[4](#4.)</sup>
#
#
# <figure>
# <img src="images/map-postcode-area-M-Manchester.jpg" style="width:500px;height:300px;">
# <figcaption>Image 2: M-Postcode districts. Source: Geopunk</figcaption>
# </figure>
#
# While inner codes seem to be far too precise for this project's aims, outer codes with the M prefix seem to give good coverage of Greater Manchester while remaining precise enough to give locally defined areas. This is explored below, details on how this is acheived is noted in further detail the comments.
#
# Unfortunately, Geopy was unable to find locations using only outer code of Postcodes. A CSV  for postcode outcode coordinates in the format of id, postcode, latitude, longitude was found from the Office of National Statistics (ONS) <sup>[5](#5.)</sup> on [free map tools](https://www.freemaptools.com/download-uk-postcode-lat-lng.htm) and used for geographical co-ordinates instead. Initially, Geopunk was scraped for postcode information, however once it was compared to this CSV it was found that many postcodes were missing from the Geopunk source. The csv file alone will be used for all postcode district geographical information as it is considerably easier to work with and any extra work to scrape websites or search for geographical co-ordinates with Geopy is superfluous.
#
# The orignal code for scraping geopunks website and using Geopy for is left below for reference of the first method acheived for geographical location. It has been changed to a Markdown cell to save computational time and can be viewed in the dropdown below.

# %% [markdown]
# <details>
# <summary>Old code</summary>
#
# ```python
#
# # Scrape geopunk for M-Postcode list
#
# # open site to bs4 object
# with urlopen("https://geopunk.co.uk/postcode-areas/M") as fp:
#     soup = BeautifulSoup(fp)
#
# # Extract list as result set.
# # Note the list of postcodes are in links on the website so first all links are extracted.
# res_set = soup.find('a').find_all('a')
#
# # Next the text form the links is converted to a list; a pattern match function has been added to the list comprehension so only 'Mx'
# # Postcodes have been extracted.
#
# #Search for postcodes beginning with M then a digit
# pattern1 = re.compile("M\d")
#
# #Search for postcodes with a space to make distinction between full and partial post codes
# pattern2 = re.compile(" ")
#
# # Create DataFrame (list name is old syntax)
# list_PC = pd.DataFrame([link.text for link in res_set if (pattern1.match(link.text) is not None) and (pattern2.search(link.text) is None)],
#                       columns = ['Postcode_District'])
#
# # Obtain geographical information using geopy (method1)
# MCR_geo1 = [geolocator.geocode({'postalcode':PC, 'city':'Manchester','country':'United Kingdom'}) for PC in list_PC.Postcode_District]
#
# # Obtain geographical information using geopy (method2)
# MCR_geo2 = [geolocator.geocode('{}, Manchester, United Kingdom'.format(PC)) for PC in list_PC.Postcode_District]
#
# ```
#
# Neither of these methods provided sufficient results for the geographical locations of the postcodes. Further inspection of Nominatim.openstreetmap showed very little mention of postcodes in the Manchester area so this method of obtaining geographical coordinates was abandoned.
#
# </details>

# %% [markdown]
# Geographical coordinates for the M-Postcode Districts extracted from the postcode outcodes ONS csv file and loaded into a DataFrame.

# %%
# Get DataFrame of all UK Postcodes. Note there is some kwargs passed for 
# formatting purposes and ease of use.
URL = 'https://www.freemaptools.com/download/outcode-postcodes/postcode-outcodes.csv'
UK_PC = pd.read_csv(URL, usecols=[1,2,3],header = 0,
                    names = ['Postcode_District', 'Latitude','Longitude'])

# Extract M- only postcodes
MP_ONS = UK_PC.loc[UK_PC.Postcode_District.str.match('M\d')]\
            .reset_index(drop=True)

# Drop Non geographic postcode M61 - See link 5
MP_ONS = MP_ONS[MP_ONS.Postcode_District != 'M61']

# %% [markdown]
# This list of postcodes is compared to Wikipedia's [M postcode area](https://en.wikipedia.org/wiki/M_postcode_area)<sup>[6](#6.)</sup> page to ensure no postcodes are missing.

# %% [markdown]
# Extract postcodes from Wikipedia:

# %%
with urlopen("https://en.wikipedia.org/wiki/M_postcode_area") as fp:
    soup = BeautifulSoup(fp)

# %%
# convert to list of strings and copy relevant table to Pandas df
table = cleanhtml(soup)[1]

# table = np.array(table).reshape(len(table)//4,4)
MP_w_f = pd.DataFrame(table, columns = table[0])
MP_w_f = MP_w_f.drop(MP_w_f.index[0])

# Drop Non geographic postcode M61 - See link 5
MP_w_f = MP_w_f[MP_w_f['Postcode district'] != 'M61']

# We can also see in the dataframe that M60 and M99 are non-residential so are
# also dropped
MP_w_f = MP_w_f[(MP_w_f['Postcode district'].str.match('M60') == False)]
MP_w_f = MP_w_f[MP_w_f['Postcode district'] != 'M99']

# Merge M3 Postcode
# Remove post code sector information
cleaner2 = re.compile('\((.*?)\)')
MP_w_f['Postcode district'] = [re.sub(cleaner2, '', i) 
                              for i in MP_w_f['Postcode district']]

# Merge columns
MP_W = MP_w_f.groupby(by = MP_w_f['Postcode district'])\
       .aggregate(lambda x: ', '.join(x)).reset_index()

# %% [markdown]
# As can be seen in the comments above some cleaning of the wikipedia table was required to produce a final dataframe of M-Postcodes (MP_W), including the removal of non-residential postcodes. Checking the ONS csv dataframe we see that the M60 and M99 postcodes also exist here. As such, they are also removed from this dataframe.

# %%
MP_ONS = MP_ONS[MP_ONS.Postcode_District != 'M60']
MP_ONS = MP_ONS[MP_ONS.Postcode_District != 'M99']

# %% [markdown]
# Finally, we check Wikipedia and ONS csv match, first by ensuring they have the same length and then that the sort postcode values match for all indices:

# %%
len(MP_W) == len(MP_ONS)
# Out:
# True

# %%
MP_match = [(i, MP_W["Postcode district"].sort_values().iloc[i] 
            == MP_ONS["Postcode_District"].sort_values().iloc[i]) 
            for i in range(len(MP_W))]

# %% [markdown]
# Exploring the values for MPC match we can see the 43 Postcodes match.

# %% [markdown]
# Mapping Manchster using M1 as centre

# %%
MPC_map = folium.Map(location=[MP_ONS.iloc[0,1], MP_ONS.iloc[0,2]], zoom_start=11)

for lat, lng, label in zip(MP_ONS['Latitude'], MP_ONS['Longitude'], MP_ONS['Postcode_District']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(MPC_map)  
    

MPC_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_823005e63d2b48359b7de795f5c605d0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_823005e63d2b48359b7de795f5c605d0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_823005e63d2b48359b7de795f5c605d0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_823005e63d2b48359b7de795f5c605d0%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53.47734%2C-2.23508%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #### <b>Nearby 'districts'</b>
#
# The final option for determing the areas used in analysis is searching for areas using the HERE api. All areas with the type 'district' whithin 10km of the centre of Manchester were found (88 districts). Note, the definition of districts here may be loosely defined.

# %%
# Find geographical coordinates of Manchester using HERE API on geopy geocode
# function (loaded at beginning of Notebook)

# Note: the API key generated expires after one hour
api_key = 'uwLO-Zkn-5dBE8Wj70tNZ4fr4RGospV1dlli_enI3-o' 
geolocator = Here(apikey=api_key)

m_loc = geolocator.geocode('Manchester')
m_lat = m_loc.latitude
m_lng = m_loc.longitude

# %%
# There is no available function for HERE browse entrypoint so a set of search 
# parameters are passed to the entrypoint to find nearby districts

URL = 'https://browse.search.hereapi.com/v1/browse'
PARAMS = {'at':str(m_lat)+','+str(m_lng),'apikey':api_key,
          'in':'circle:53.4794892,-2.2451148;r=10000','types':'district',
          'limit':'100','additionaldata':'IncludeShapeLevel,district'} 

r = requests.get(url = URL, params = PARAMS) 
data = r.json()

# %%
data
# Out:
# {'items': [{'title': 'Spinningfields, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796492',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Spinningfields, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Spinningfields',
#     'postalCode': 'M3 3'},
#    'position': {'lat': 53.48068, 'lng': -2.25242},
#    'distance': 272,
#    'mapView': {'west': -2.25785,
#     'south': 53.47833,
#     'east': -2.24796,
#     'north': 53.48352}},
#   {'title': 'Shopping District, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796491',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Shopping District, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Shopping District'},
#    'position': {'lat': 53.48216, 'lng': -2.24574},
#    'distance': 347,
#    'mapView': {'west': -2.25324,
#     'south': 53.47975,
#     'east': -2.23736,
#     'north': 53.486}},
#   {'title': 'Manchester Central, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796454',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Manchester Central, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Manchester Central',
#     'postalCode': 'M2 3'},
#    'position': {'lat': 53.4772, 'lng': -2.24447},
#    'distance': 389,
#    'mapView': {'west': -2.25196,
#     'south': 53.47395,
#     'east': -2.24016,
#     'north': 53.4811}},
#   {'title': 'China Town, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796448',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'China Town, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'China Town',
#     'postalCode': 'M1 4'},
#    'position': {'lat': 53.47888, 'lng': -2.23971},
#    'distance': 603,
#    'mapView': {'west': -2.24229,
#     'south': 53.47755,
#     'east': -2.23674,
#     'north': 53.48039}},
#   {'title': 'Castlefield, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796445',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Castlefield, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Castlefield',
#     'postalCode': 'M3 4'},
#    'position': {'lat': 53.47648, 'lng': -2.25666},
#    'distance': 629,
#    'mapView': {'west': -2.26361,
#     'south': 53.47211,
#     'east': -2.24955,
#     'north': 53.4818}},
#   {'title': 'Deansgate Locks, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796449',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Deansgate Locks, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Deansgate Locks',
#     'postalCode': 'M15 4'},
#    'position': {'lat': 53.47318, 'lng': -2.25104},
#    'distance': 730,
#    'mapView': {'west': -2.25826,
#     'south': 53.46946,
#     'east': -2.24125,
#     'north': 53.47448}},
#   {'title': 'Blackfriars, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796441',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Blackfriars, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Blackfriars',
#     'postalCode': 'M3 7'},
#    'position': {'lat': 53.48701, 'lng': -2.25042},
#    'distance': 831,
#    'mapView': {'west': -2.25754,
#     'south': 53.4819,
#     'east': -2.24478,
#     'north': 53.49009}},
#   {'title': 'The Gay Village, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796495',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'The Gay Village, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'The Gay Village',
#     'postalCode': 'M1 3'},
#    'position': {'lat': 53.47787, 'lng': -2.23649},
#    'distance': 833,
#    'mapView': {'west': -2.24016,
#     'south': 53.47567,
#     'east': -2.2339,
#     'north': 53.48041}},
#   {'title': 'Victoria, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796497',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Victoria, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Victoria',
#     'postalCode': 'M60 0'},
#    'position': {'lat': 53.48691, 'lng': -2.23925},
#    'distance': 1027,
#    'mapView': {'west': -2.24584,
#     'south': 53.48449,
#     'east': -2.23507,
#     'north': 53.4894}},
#   {'title': 'Northern Quarter, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796457',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Northern Quarter, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Northern Quarter',
#     'postalCode': 'M1 1'},
#    'position': {'lat': 53.48317, 'lng': -2.23301},
#    'distance': 1114,
#    'mapView': {'west': -2.23937,
#     'south': 53.47969,
#     'east': -2.2268,
#     'north': 53.48635}},
#   {'title': 'Greenquarter, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796453',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Greenquarter, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Greenquarter',
#     'postalCode': 'M4 4'},
#    'position': {'lat': 53.49019, 'lng': -2.24016},
#    'distance': 1307,
#    'mapView': {'west': -2.24181,
#     'south': 53.48885,
#     'east': -2.23832,
#     'north': 53.49173}},
#   {'title': 'Hulme, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344231',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Hulme, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Hulme',
#     'postalCode': 'M15 5'},
#    'position': {'lat': 53.46724, 'lng': -2.24973},
#    'distance': 1376,
#    'mapView': {'west': -2.25975,
#     'south': 53.45781,
#     'east': -2.24402,
#     'north': 53.4713}},
#   {'title': 'Ancoats, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796438',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Ancoats, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Ancoats',
#     'postalCode': 'M4 5'},
#    'position': {'lat': 53.48579, 'lng': -2.23054},
#    'distance': 1387,
#    'mapView': {'west': -2.23595,
#     'south': 53.48243,
#     'east': -2.22443,
#     'north': 53.489}},
#   {'title': 'Piccadilly, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796487',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Piccadilly, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Piccadilly',
#     'postalCode': 'M1 2'},
#    'position': {'lat': 53.47795, 'lng': -2.22717},
#    'distance': 1439,
#    'mapView': {'west': -2.23977,
#     'south': 53.47342,
#     'east': -2.21779,
#     'north': 53.48219}},
#   {'title': 'University District, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796496',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'University District, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'University District',
#     'postalCode': 'M13 9'},
#    'position': {'lat': 53.46633, 'lng': -2.23549},
#    'distance': 1716,
#    'mapView': {'west': -2.24452,
#     'south': 53.46039,
#     'east': -2.22608,
#     'north': 53.47755}},
#   {'title': 'New Islington, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796455',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'New Islington, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'New Islington',
#     'postalCode': 'M4 6'},
#    'position': {'lat': 53.4824, 'lng': -2.2224},
#    'distance': 1771,
#    'mapView': {'west': -2.22844,
#     'south': 53.47899,
#     'east': -2.21592,
#     'north': 53.48525}},
#   {'title': 'Manchester Science Park, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344238',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Manchester Science Park, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Manchester Science Park',
#     'postalCode': 'M15 6'},
#    'position': {'lat': 53.46511, 'lng': -2.23703},
#    'distance': 1788,
#    'mapView': {'west': -2.23958,
#     'south': 53.46044,
#     'east': -2.23541,
#     'north': 53.46516}},
#   {'title': 'Ordsall, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796469',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Ordsall, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Ordsall',
#     'postalCode': 'M5 3'},
#    'position': {'lat': 53.4728, 'lng': -2.27448},
#    'distance': 1864,
#    'mapView': {'west': -2.28345,
#     'south': 53.46681,
#     'east': -2.26356,
#     'north': 53.47914}},
#   {'title': 'Cheetham Hill, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796447',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Cheetham Hill, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Cheetham Hill',
#     'postalCode': 'M8 8'},
#    'position': {'lat': 53.4973, 'lng': -2.24177},
#    'distance': 2021,
#    'mapView': {'west': -2.25532,
#     'south': 53.48821,
#     'east': -2.22175,
#     'north': 53.51265}},
#   {'title': 'Ardwick, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344209',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Ardwick, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Ardwick',
#     'postalCode': 'M12 6'},
#    'position': {'lat': 53.46932, 'lng': -2.22262},
#    'distance': 2072,
#    'mapView': {'west': -2.22984,
#     'south': 53.46676,
#     'east': -2.20707,
#     'north': 53.48283}},
#   {'title': 'Pendleton, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796486',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Pendleton, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Pendleton',
#     'postalCode': 'M5 4'},
#    'position': {'lat': 53.48686, 'lng': -2.28174},
#    'distance': 2328,
#    'mapView': {'west': -2.29149,
#     'south': 53.47797,
#     'east': -2.27555,
#     'north': 53.49179}},
#   {'title': 'Collyhurst, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344219',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Collyhurst, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Collyhurst',
#     'postalCode': 'M40 7'},
#    'position': {'lat': 53.49499, 'lng': -2.22361},
#    'distance': 2386,
#    'mapView': {'west': -2.2316,
#     'south': 53.48837,
#     'east': -2.2129,
#     'north': 53.50297}},
#   {'title': 'Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344207',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Manchester'},
#    'position': {'lat': 53.46054, 'lng': -2.22968},
#    'distance': 2466,
#    'mapView': {'west': -2.45498,
#     'south': 53.34702,
#     'east': -2.02321,
#     'north': 53.57253}},
#   {'title': 'Moss Side, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344241',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Moss Side, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Moss Side',
#     'postalCode': 'M16 7'},
#    'position': {'lat': 53.45746, 'lng': -2.25237},
#    'distance': 2474,
#    'mapView': {'west': -2.25848,
#     'south': 53.45165,
#     'east': -2.24492,
#     'north': 53.46041}},
#   {'title': 'Broughton, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796444',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Broughton, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Broughton',
#     'postalCode': 'M7 2'},
#    'position': {'lat': 53.50211, 'lng': -2.26482},
#    'distance': 2720,
#    'mapView': {'west': -2.2749,
#     'south': 53.48398,
#     'east': -2.24518,
#     'north': 53.51804}},
#   {'title': 'Old Trafford, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344246',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Old Trafford, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Old Trafford',
#     'postalCode': 'M16 7'},
#    'position': {'lat': 53.4555, 'lng': -2.2637},
#    'distance': 2857,
#    'mapView': {'west': -2.30206,
#     'south': 53.45091,
#     'east': -2.25651,
#     'north': 53.47112}},
#   {'title': 'Salford Quays, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796489',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Salford Quays, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Salford Quays',
#     'postalCode': 'M50 3'},
#    'position': {'lat': 53.47067, 'lng': -2.29065},
#    'distance': 2946,
#    'mapView': {'west': -2.30059,
#     'south': 53.4651,
#     'east': -2.27742,
#     'north': 53.47688}},
#   {'title': 'Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344459',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'Salford'},
#    'position': {'lat': 53.4922, 'lng': -2.28833},
#    'distance': 2971,
#    'mapView': {'west': -2.33054,
#     'south': 53.4651,
#     'east': -2.24488,
#     'north': 53.51815}},
#   {'title': 'Miles Platting, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344240',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Miles Platting, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Miles Platting',
#     'postalCode': 'M40 8'},
#    'position': {'lat': 53.49535, 'lng': -2.21199},
#    'distance': 2996,
#    'mapView': {'west': -2.22197,
#     'south': 53.48273,
#     'east': -2.19977,
#     'north': 53.50577}},
#   {'title': 'Beswick, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796440',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Beswick, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Beswick',
#     'postalCode': 'M11 3'},
#    'position': {'lat': 53.47816, 'lng': -2.20323},
#    'distance': 3016,
#    'mapView': {'west': -2.21117,
#     'south': 53.47399,
#     'east': -2.19072,
#     'north': 53.48195}},
#   {'title': 'Whalley Range, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344259',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Whalley Range, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Whalley Range',
#     'postalCode': 'M16 8'},
#    'position': {'lat': 53.45221, 'lng': -2.25753},
#    'distance': 3101,
#    'mapView': {'west': -2.26756,
#     'south': 53.43951,
#     'east': -2.24437,
#     'north': 53.45882}},
#   {'title': 'The Curry Mile, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796494',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'The Curry Mile, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'The Curry Mile',
#     'postalCode': 'M14 5'},
#    'position': {'lat': 53.45489, 'lng': -2.22426},
#    'distance': 3190,
#    'mapView': {'west': -2.22861,
#     'south': 53.45189,
#     'east': -2.22104,
#     'north': 53.46262}},
#   {'title': 'Firswood, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344227',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Firswood, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Firswood',
#     'postalCode': 'M16 0'},
#    'position': {'lat': 53.45288, 'lng': -2.27333},
#    'distance': 3388,
#    'mapView': {'west': -2.28789,
#     'south': 53.44683,
#     'east': -2.26443,
#     'north': 53.46142}},
#   {'title': 'MediaCityUK, Salford, England, United Kingdom',
#    'id': 'here:cm:namedplace:26590929',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'MediaCityUK, Salford, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Salford',
#     'district': 'MediaCityUK',
#     'postalCode': 'M50 2'},
#    'position': {'lat': 53.47357, 'lng': -2.29923},
#    'distance': 3408,
#    'mapView': {'west': -2.30525,
#     'south': 53.46949,
#     'east': -2.29376,
#     'north': 53.47547}},
#   {'title': 'Sportcity, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796493',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Sportcity, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Sportcity',
#     'postalCode': 'M11 4'},
#    'position': {'lat': 53.48674, 'lng': -2.19771},
#    'distance': 3469,
#    'mapView': {'west': -2.2062,
#     'south': 53.48069,
#     'east': -2.18783,
#     'north': 53.4911}},
#   {'title': 'Rusholme, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344252',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Rusholme, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Rusholme',
#     'postalCode': 'M14 5'},
#    'position': {'lat': 53.45226, 'lng': -2.22253},
#    'distance': 3500,
#    'mapView': {'west': -2.24533,
#     'south': 53.44913,
#     'east': -2.20703,
#     'north': 53.46094}},
#   {'title': 'Old Trafford, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796458',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Old Trafford, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Old Trafford',
#     'postalCode': 'M16 0'},
#    'position': {'lat': 53.45845, 'lng': -2.29143},
#    'distance': 3676,
#    'mapView': {'west': -2.29614,
#     'south': 53.45401,
#     'east': -2.28628,
#     'north': 53.46221}},
#   {'title': 'Longsight, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344236',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Longsight, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Longsight',
#     'postalCode': 'M12 4'},
#    'position': {'lat': 53.45698, 'lng': -2.20051},
#    'distance': 4064,
#    'mapView': {'west': -2.22444,
#     'south': 53.44664,
#     'east': -2.1818,
#     'north': 53.47315}},
#   {'title': 'Trafford Park, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344256',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Trafford Park, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Trafford Park',
#     'postalCode': 'M17 1'},
#    'position': {'lat': 53.46813, 'lng': -2.30837},
#    'distance': 4147,
#    'mapView': {'west': -2.34816,
#     'south': 53.45574,
#     'east': -2.28419,
#     'north': 53.48071}},
#   {'title': 'Crumpsall, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344220',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Crumpsall, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Crumpsall',
#     'postalCode': 'M8 5'},
#    'position': {'lat': 53.51659, 'lng': -2.23643},
#    'distance': 4193,
#    'mapView': {'west': -2.25544,
#     'south': 53.50945,
#     'east': -2.22096,
#     'north': 53.53332}},
#   {'title': 'Clayton, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344218',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Clayton, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Clayton',
#     'postalCode': 'M11 4'},
#    'position': {'lat': 53.48324, 'lng': -2.18383},
#    'distance': 4314,
#    'mapView': {'west': -2.19986,
#     'south': 53.47904,
#     'east': -2.16613,
#     'north': 53.49164}},
#   {'title': 'Harpurhey, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344229',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Harpurhey, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Harpurhey',
#     'postalCode': 'M9 4'},
#    'position': {'lat': 53.51261, 'lng': -2.21398},
#    'distance': 4331,
#    'mapView': {'west': -2.22783,
#     'south': 53.50228,
#     'east': -2.20685,
#     'north': 53.52498}},
#   {'title': 'Fallowfield, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344226',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Fallowfield, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Fallowfield',
#     'postalCode': 'M14 6'},
#    'position': {'lat': 53.4429, 'lng': -2.22224},
#    'distance': 4442,
#    'mapView': {'west': -2.24514,
#     'south': 53.43528,
#     'east': -2.21539,
#     'north': 53.45507}},
#   {'title': 'Chorlton, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:25835829',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Chorlton, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Chorlton',
#     'postalCode': 'M21 0'},
#    'position': {'lat': 53.44253, 'lng': -2.27656},
#    'distance': 4515,
#    'mapView': {'west': -2.30839,
#     'south': 53.41611,
#     'east': -2.24418,
#     'north': 53.45019}},
#   {'title': 'Chorlton cum Hardy, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344217',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Chorlton cum Hardy, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Chorlton cum Hardy',
#     'postalCode': 'M21 0'},
#    'position': {'lat': 53.44253, 'lng': -2.27656},
#    'distance': 4515,
#    'mapView': {'west': -2.30839,
#     'south': 53.41611,
#     'east': -2.24418,
#     'north': 53.45019}},
#   {'title': 'Openshaw, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344247',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Openshaw, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Openshaw',
#     'postalCode': 'M11 2'},
#    'position': {'lat': 53.47344, 'lng': -2.18094},
#    'distance': 4539,
#    'mapView': {'west': -2.20592,
#     'south': 53.4682,
#     'east': -2.15001,
#     'north': 53.48089}},
#   {'title': 'Blackley, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796443',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Blackley, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Blackley',
#     'postalCode': 'M9 8'},
#    'position': {'lat': 53.51749, 'lng': -2.20448},
#    'distance': 5130,
#    'mapView': {'west': -2.22715,
#     'south': 53.50392,
#     'east': -2.18217,
#     'north': 53.52984}},
#   {'title': 'Withington, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344261',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Withington, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Withington',
#     'postalCode': 'M20 3'},
#    'position': {'lat': 53.43461, 'lng': -2.22786},
#    'distance': 5190,
#    'mapView': {'west': -2.24541,
#     'south': 53.42181,
#     'east': -2.20978,
#     'north': 53.44316}},
#   {'title': 'Newton Heath, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344244',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Newton Heath, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Newton Heath',
#     'postalCode': 'M40 2'},
#    'position': {'lat': 53.50307, 'lng': -2.18049},
#    'distance': 5215,
#    'mapView': {'west': -2.20901,
#     'south': 53.48828,
#     'east': -2.16338,
#     'north': 53.51213}},
#   {'title': 'Moston, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344242',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Moston, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Moston',
#     'postalCode': 'M40 9'},
#    'position': {'lat': 53.51386, 'lng': -2.19433},
#    'distance': 5241,
#    'mapView': {'west': -2.21223,
#     'south': 53.4982,
#     'east': -2.1685,
#     'north': 53.52782}},
#   {'title': 'Levenshulme, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344234',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Levenshulme, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Levenshulme',
#     'postalCode': 'M19 3'},
#    'position': {'lat': 53.44485, 'lng': -2.19159},
#    'distance': 5408,
#    'mapView': {'west': -2.19443,
#     'south': 53.4329,
#     'east': -2.1661,
#     'north': 53.45367}},
#   {'title': 'Gorton, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344228',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Gorton, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Gorton',
#     'postalCode': 'M18 7'},
#    'position': {'lat': 53.46111, 'lng': -2.17306},
#    'distance': 5415,
#    'mapView': {'west': -2.19103,
#     'south': 53.44918,
#     'east': -2.14906,
#     'north': 53.46971}},
#   {'title': 'Ladybarn, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344233',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Ladybarn, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Ladybarn',
#     'postalCode': 'M14 6'},
#    'position': {'lat': 53.43465, 'lng': -2.21248},
#    'distance': 5545,
#    'mapView': {'west': -2.2196,
#     'south': 53.4335,
#     'east': -2.20024,
#     'north': 53.44953}},
#   {'title': 'Stretford, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344254',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Stretford, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Stretford',
#     'postalCode': 'M32 9'},
#    'position': {'lat': 53.44571, 'lng': -2.31382},
#    'distance': 5724,
#    'mapView': {'west': -2.34077,
#     'south': 53.42944,
#     'east': -2.28608,
#     'north': 53.46527}},
#   {'title': 'Eccles, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344224',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Eccles, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Eccles',
#     'postalCode': 'M30 0'},
#    'position': {'lat': 53.48342, 'lng': -2.34134},
#    'distance': 6142,
#    'mapView': {'west': -2.41055,
#     'south': 53.45643,
#     'east': -2.32496,
#     'north': 53.50135}},
#   {'title': 'Abbey Hey, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344208',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Abbey Hey, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Abbey Hey',
#     'postalCode': 'M18 8'},
#    'position': {'lat': 53.46867, 'lng': -2.15607},
#    'distance': 6252,
#    'mapView': {'west': -2.18067,
#     'south': 53.45954,
#     'east': -2.14708,
#     'north': 53.47019}},
#   {'title': 'Charlestown, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796446',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Charlestown, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Charlestown',
#     'postalCode': 'M9 7'},
#    'position': {'lat': 53.52372, 'lng': -2.18969},
#    'distance': 6271,
#    'mapView': {'west': -2.20072,
#     'south': 53.52039,
#     'east': -2.17596,
#     'north': 53.53182}},
#   {'title': 'Higher Blackley, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344230',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Higher Blackley, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Higher Blackley',
#     'postalCode': 'M9 6'},
#    'position': {'lat': 53.53208, 'lng': -2.20708},
#    'distance': 6453,
#    'mapView': {'west': -2.22535,
#     'south': 53.5231,
#     'east': -2.19388,
#     'north': 53.54204}},
#   {'title': 'Prestwich, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344249',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Prestwich, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Prestwich',
#     'postalCode': 'M25 1'},
#    'position': {'lat': 53.53344, 'lng': -2.28575},
#    'distance': 6468,
#    'mapView': {'west': -2.30577,
#     'south': 53.51292,
#     'east': -2.24182,
#     'north': 53.55988}},
#   {'title': 'Failsworth, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344225',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Failsworth, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Failsworth',
#     'postalCode': 'M35 0'},
#    'position': {'lat': 53.50846, 'lng': -2.16337},
#    'distance': 6495,
#    'mapView': {'west': -2.17701,
#     'south': 53.49227,
#     'east': -2.12182,
#     'north': 53.52258}},
#   {'title': 'intu Trafford Centre, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20460946',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'intu Trafford Centre, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'intu Trafford Centre',
#     'postalCode': 'M41 7'},
#    'position': {'lat': 53.46229, 'lng': -2.34636},
#    'distance': 6742,
#    'mapView': {'west': -2.36511,
#     'south': 53.45916,
#     'east': -2.33641,
#     'north': 53.47179}},
#   {'title': 'New Moston, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344243',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'New Moston, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'New Moston',
#     'postalCode': 'M40 3'},
#    'position': {'lat': 53.51665, 'lng': -2.16799},
#    'distance': 6745,
#    'mapView': {'west': -2.17582,
#     'south': 53.51203,
#     'east': -2.15565,
#     'north': 53.52366}},
#   {'title': 'Burnage, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344214',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Burnage, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Burnage',
#     'postalCode': 'M20 6'},
#    'position': {'lat': 53.42136, 'lng': -2.21728},
#    'distance': 6803,
#    'mapView': {'west': -2.21922,
#     'south': 53.41155,
#     'east': -2.18685,
#     'north': 53.44932}},
#   {'title': 'Droylsden, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344223',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Droylsden, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Droylsden',
#     'postalCode': 'M43 7'},
#    'position': {'lat': 53.47969, 'lng': -2.14553},
#    'distance': 6830,
#    'mapView': {'west': -2.1788,
#     'south': 53.47248,
#     'east': -2.11797,
#     'north': 53.50805}},
#   {'title': 'Swinton, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344255',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Swinton, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Swinton',
#     'postalCode': 'M27 4'},
#    'position': {'lat': 53.51151, 'lng': -2.33895},
#    'distance': 6942,
#    'mapView': {'west': -2.36914,
#     'south': 53.49566,
#     'east': -2.29125,
#     'north': 53.53711}},
#   {'title': 'Didsbury, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344222',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Didsbury, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Didsbury',
#     'postalCode': 'M20 6'},
#    'position': {'lat': 53.41755, 'lng': -2.23158},
#    'distance': 6993,
#    'mapView': {'west': -2.26491,
#     'south': 53.40585,
#     'east': -2.21291,
#     'north': 53.43656}},
#   {'title': 'Heaton Chapel, Stockport, England, United Kingdom',
#    'id': 'here:cm:namedplace:20343647',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Heaton Chapel, Stockport, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Stockport',
#     'district': 'Heaton Chapel',
#     'postalCode': 'SK4 5'},
#    'position': {'lat': 53.42867, 'lng': -2.17563},
#    'distance': 7450,
#    'mapView': {'west': -2.19115,
#     'south': 53.42405,
#     'east': -2.16309,
#     'north': 53.43921}},
#   {'title': 'Reddish, Stockport, England, United Kingdom',
#    'id': 'here:cm:namedplace:20343654',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Reddish, Stockport, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Stockport',
#     'district': 'Reddish',
#     'postalCode': 'SK5 6'},
#    'position': {'lat': 53.43813, 'lng': -2.15969},
#    'distance': 7485,
#    'mapView': {'west': -2.17161,
#     'south': 53.4355,
#     'east': -2.14433,
#     'north': 53.45485}},
#   {'title': 'Sale, England, United Kingdom',
#    'id': 'here:cm:namedplace:20343614',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Sale, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Sale',
#     'district': 'Sale'},
#    'position': {'lat': 53.42552, 'lng': -2.3164},
#    'distance': 7499,
#    'mapView': {'west': -2.36512,
#     'south': 53.40722,
#     'east': -2.26828,
#     'north': 53.43649}},
#   {'title': 'Urmston, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344258',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Urmston, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Urmston',
#     'postalCode': 'M41 9'},
#    'position': {'lat': 53.44681, 'lng': -2.35283},
#    'distance': 7796,
#    'mapView': {'west': -2.41092,
#     'south': 53.43045,
#     'east': -2.32809,
#     'north': 53.4755}},
#   {'title': 'Audenshaw, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344211',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Audenshaw, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Audenshaw',
#     'postalCode': 'M34 5'},
#    'position': {'lat': 53.47124, 'lng': -2.12918},
#    'distance': 7967,
#    'mapView': {'west': -2.15007,
#     'south': 53.45987,
#     'east': -2.09379,
#     'north': 53.48636}},
#   {'title': 'Heaton Mersey, Stockport, England, United Kingdom',
#    'id': 'here:cm:namedplace:20343648',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Heaton Mersey, Stockport, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Stockport',
#     'district': 'Heaton Mersey',
#     'postalCode': 'SK4 3'},
#    'position': {'lat': 53.41342, 'lng': -2.19964},
#    'distance': 8045,
#    'mapView': {'west': -2.21518,
#     'south': 53.40621,
#     'east': -2.18969,
#     'north': 53.42642}},
#   {'title': 'Northenden, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344245',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Northenden, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Northenden',
#     'postalCode': 'M22 4'},
#    'position': {'lat': 53.40715, 'lng': -2.25935},
#    'distance': 8087,
#    'mapView': {'west': -2.26987,
#     'south': 53.39146,
#     'east': -2.24088,
#     'north': 53.41611}},
#   {'title': 'East Didsbury, Stockport, England, United Kingdom',
#    'id': 'here:cm:namedplace:23796451',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'East Didsbury, Stockport, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Stockport',
#     'district': 'East Didsbury',
#     'postalCode': 'M20 5'},
#    'position': {'lat': 53.40698, 'lng': -2.22534},
#    'distance': 8222,
#    'mapView': {'west': -2.23842,
#     'south': 53.39892,
#     'east': -2.21219,
#     'north': 53.41492}},
#   {'title': 'Wythenshawe, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344263',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Wythenshawe, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Wythenshawe',
#     'postalCode': 'M23 0'},
#    'position': {'lat': 53.40769, 'lng': -2.28299},
#    'distance': 8312,
#    'mapView': {'west': -2.31671,
#     'south': 53.35805,
#     'east': -2.23727,
#     'north': 53.41934}},
#   {'title': 'Brooklands, Sale, England, United Kingdom',
#    'id': 'here:cm:namedplace:20343615',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Brooklands, Sale, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Sale',
#     'district': 'Brooklands',
#     'postalCode': 'M33 3'},
#    'position': {'lat': 53.41766, 'lng': -2.32203},
#    'distance': 8426,
#    'mapView': {'west': -2.33127,
#     'south': 53.40583,
#     'east': -2.30201,
#     'north': 53.42434}},
#   {'title': 'Middleton, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344239',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Middleton, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Middleton',
#     'postalCode': 'M24 6'},
#    'position': {'lat': 53.55043, 'lng': -2.19738},
#    'distance': 8577,
#    'mapView': {'west': -2.2484,
#     'south': 53.52756,
#     'east': -2.14123,
#     'north': 53.58981}},
#   {'title': 'Daisy Nook, Manchester, England, United Kingdom',
#    'id': 'here:cm:poi:1040381090',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Daisy Nook, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Daisy Nook'},
#    'position': {'lat': 53.50117, 'lng': -2.12387},
#    'distance': 8602,
#    'mapView': {'west': -2.12486,
#     'south': 53.50092,
#     'east': -2.12386,
#     'north': 53.50128}},
#   {'title': 'Whitefield, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344260',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Whitefield, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Whitefield',
#     'postalCode': 'M45 8'},
#    'position': {'lat': 53.55228, 'lng': -2.29648},
#    'distance': 8676,
#    'mapView': {'west': -2.31671,
#     'south': 53.53619,
#     'east': -2.26157,
#     'north': 53.57031}},
#   {'title': 'Sharston Industrial Area, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344253',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Sharston Industrial Area, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Sharston Industrial Area',
#     'postalCode': 'M22 4'},
#    'position': {'lat': 53.39997, 'lng': -2.25509},
#    'distance': 8864,
#    'mapView': {'west': -2.26534,
#     'south': 53.3956,
#     'east': -2.2449,
#     'north': 53.40156}},
#   {'title': 'Worsley, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344262',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Worsley, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Worsley',
#     'postalCode': 'M28 2'},
#    'position': {'lat': 53.50055, 'lng': -2.38097},
#    'distance': 9053,
#    'mapView': {'west': -2.4521,
#     'south': 53.48467,
#     'east': -2.35198,
#     'north': 53.53869}},
#   {'title': 'Unsworth, Bury, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344032',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Unsworth, Bury, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Bury',
#     'district': 'Unsworth',
#     'postalCode': 'BL9 8'},
#    'position': {'lat': 53.56088, 'lng': -2.27819},
#    'distance': 9245,
#    'mapView': {'west': -2.29589,
#     'south': 53.55166,
#     'east': -2.25322,
#     'north': 53.58375}},
#   {'title': 'Baguley, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344212',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Baguley, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Baguley',
#     'postalCode': 'M23 1'},
#    'position': {'lat': 53.39909, 'lng': -2.28561},
#    'distance': 9279,
#    'mapView': {'west': -2.29415,
#     'south': 53.38874,
#     'east': -2.2768,
#     'north': 53.40101}},
#   {'title': 'Denton, Manchester, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344221',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Denton, Manchester, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Manchester',
#     'district': 'Denton',
#     'postalCode': 'M34 6'},
#    'position': {'lat': 53.45601, 'lng': -2.11368},
#    'distance': 9317,
#    'mapView': {'west': -2.15811,
#     'south': 53.42932,
#     'east': -2.08913,
#     'north': 53.46443}},
#   {'title': 'Hawksley Industrial Estate, Oldham, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344293',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Hawksley Industrial Estate, Oldham, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Oldham',
#     'district': 'Hawksley Industrial Estate',
#     'postalCode': 'OL8 4'},
#    'position': {'lat': 53.529, 'lng': -2.1344},
#    'distance': 9346,
#    'mapView': {'west': -2.13686,
#     'south': 53.52571,
#     'east': -2.13292,
#     'north': 53.52907}},
#   {'title': 'Gatley, Cheadle, England, United Kingdom',
#    'id': 'here:cm:namedplace:20343399',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Gatley, Cheadle, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'CHS',
#     'county': 'Cheshire',
#     'city': 'Cheadle',
#     'district': 'Gatley',
#     'postalCode': 'SK8 4'},
#    'position': {'lat': 53.39264, 'lng': -2.23507},
#    'distance': 9712,
#    'mapView': {'west': -2.24709,
#     'south': 53.39097,
#     'east': -2.22226,
#     'north': 53.39913}},
#   {'title': 'Birch, Heywood, England, United Kingdom',
#    'id': 'here:cm:poi:1010639169',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Birch, Heywood, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Heywood',
#     'district': 'Birch'},
#    'position': {'lat': 53.56602, 'lng': -2.22444},
#    'distance': 9743,
#    'mapView': {'west': -2.22472,
#     'south': 53.56598,
#     'east': -2.22417,
#     'north': 53.56604}},
#   {'title': 'Bardsley, Oldham, England, United Kingdom',
#    'id': 'here:cm:namedplace:20344284',
#    'resultType': 'locality',
#    'localityType': 'district',
#    'address': {'label': 'Bardsley, Oldham, England, United Kingdom',
#     'countryCode': 'GBR',
#     'countryName': 'United Kingdom',
#     'state': 'England',
#     'countyCode': 'LAN',
#     'county': 'Lancashire',
#     'city': 'Oldham',
#     'district': 'Bardsley',
#     'postalCode': 'OL8 3'},
#    'position': {'lat': 53.51446, 'lng': -2.10784},
#    'distance': 10094,
#    'mapView': {'west': -2.14582,
#     'south': 53.50419,
#     'east': -2.10051,
#     'north': 53.52771}}]}

# %% [markdown]
# The data object (dict) contains a lot of useful information, for now we are only interested in the name of the district, the geogrpaphical location and the distance from the centre of Manchester so we extract them.

# %%
# There is no available function for HERE browse entrypoint so a set of search 
# parameters are passed to the entrypoint to find nearby districts

URL = 'https://browse.search.hereapi.com/v1/browse'
PARAMS = {'at':str(m_lat)+','+str(m_lng),'apikey':api_key,
          'in':'circle:53.4794892,-2.2451148;r=10000','types':'district',
          'limit':'100','additionaldata':'IncludeShapeLevel,district'} 

r = requests.get(url = URL, params = PARAMS) 
data = r.json()

# %%
M_dist = pd.DataFrame([[item['title'].split(',')[0],item['position']['lat'],
                        item['position']['lng'],item['distance']] 
                        for item in data['items']],
                        columns = ['District','Latitude','Longitude','Distance'])

# %% [markdown]
# Finally, we will save this DataFrame to csv to avoid unnecessarily re-use of the API

# %%
# Remove filepath to push

M_dist.to_csv('~\Documents\Data_Science\Python\IBM\BotN\Project Files\Manchester\M_dist.csv')

# %% [markdown]
# M_dist can be then directly loaded from the csv file with the following code
#
# ```python
#    M_dist = pd.read_csv('filepath\M_dist.csv', index_col = 0)
# ```

# %%
# Remove cell to push

M_dist = pd.read_csv(
    '~\Documents\Data_Science\Python\IBM\BotN\Project Files\Manchester\M_dist.csv', index_col = 0)

# %%
M_dist.iloc[11]
# Out:
# District        Hulme
# Latitude     53.46724
# Longitude    -2.24973
# Distance         1376
# Name: 11, dtype: object

# %% [markdown]
# Getting boundary information

# %%
len(M_dist)
# Out:
# 85

# %%
URL = 'https://reverse.geocoder.ls.hereapi.com/6.2/reversegeocode.json'

wkt_df = pd.DataFrame([], columns=['lonlat'])

for i in range(len(M_dist)):
    PARAMS = {'apikey':api_key,'prox':str(M_dist.iloc[i,1])+','+str(M_dist.iloc[i,2])+','+str(2000),
              'mode':'retrieveAreas','additionaldata':'IncludeShapeLevel,district'}

    r = requests.get(url = URL, params = PARAMS) 
    data = r.json()

    try:
        thisone = data['Response']['View'][0]['Result'][0]['Location']['Shape']['Value']
        wkt_df.loc[i]=thisone
    except:
        pass

# %% [markdown]
# HERE's API returns Polygon information in WKT, here we convert it to geojson format

# %%
M_dist.loc[1][0]
# Out:
# 'Shopping District'

# %%
geojson_string = [geojson.dumps(mapping(loads(i))) for i in wkt_df.lonlat]

geojson_dict = [ast.literal_eval(i) for i in geojson_string]

# %%
map_test = folium.Map(location=(53.48096,-2.24881), zoom_start=16)
for i in range(len(geojson_dict)):
    folium.GeoJson(geojson_dict[i]).add_to(map_test)
map_test
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_e8caa41dda5c4cd49da4e7500d576c80%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e8caa41dda5c4cd49da4e7500d576c80%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e8caa41dda5c4cd49da4e7500d576c80%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_e8caa41dda5c4cd49da4e7500d576c80%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53.48096%2C-2.24881%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2016%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
test_latlon = (M_dist.iloc[0,1],M_dist.iloc[0,2])

geolocator.reverse(test_latlon)
# Out:
# Location(Gartside Street, Manchester, M60 9, United Kingdom, Manchester, England M60 9, GBR, (53.4806815, -2.2524236, 0.0))

# %% [markdown]
# Mapping HERE API districts

# %% [markdown]
# ### Desirability
#
# The next task will be to determine what features will be used to determine the desirabilty of the given areas. Some examples of this may be:
# * Public Transport
# * Pubs and Restaraunts
# * Green Spaces
# * Average age of community (i.e. do similar people live in the area)
# * Landmarks and points of interest (e.g Old Trafford, City of Manchester Stadium)
# * Museums and Libraries
# * Gyms and Leisure
# * Access to Healthcare

# %% [markdown]
# ## References
#
#
# ACTUAL LIFESAVER
# https://gist.github.com/drmalex07/5a54fc4f1db06a66679e
#
#
# ##### 1.
# https://ilovemanchester.com/manchester-and-salford-so-whats-the-difference
# ##### 2.
# https://geopunk.co.uk/council/Manchester-District-(B)
# ##### 3.
# https://www.geopunk.co.uk/postcode-areas/M  #### No longer in use
# ##### 4.
# https://en.wikipedia.org/wiki/Postcodes_in_the_United_Kingdom#Outward_code
# ##### 5.
# postcode-outcodes.csv, Office for National Statistics licensed under the Open Government Licence v.3.0, https://www.freemaptools.com/download-uk-postcode-lat-lng.htm
# ##### 6.
# https://en.wikipedia.org/wiki/M_postcode_area
#
# developer.here.com
#
#
#
#
# https://en.wikipedia.org/wiki/Greater_Manchester <br>
#
# https://en.wikipedia.org/wiki/Transport_in_Manchester <br>
#
# https://www.cityoftrees.org.uk/explore <br>

# %% [markdown]
# [Top](#Discovering-Manchester)
